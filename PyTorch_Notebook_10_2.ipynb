# %% [markdown]
# <a href="https://colab.research.google.com/github/PeepeR19/CSCI167_PyTorch_Notebook/blob/main/PyTorch_Notebook_10_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-_jpmb5cq
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-_jpmb5cq
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=9ac80b5d874e3109911684867313c513e52cfa8c04990d06d9a2b529ce36572f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o19r6z5i/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.125319, train error 78.47,  val loss 2.143593, percent error 80.80
# Epoch     1, train loss 1.577929, train error 61.95,  val loss 1.604778, percent error 65.30
# Epoch     2, train loss 1.448411, train error 58.83,  val loss 1.483900, percent error 59.90
# Epoch     3, train loss 1.361039, train error 54.62,  val loss 1.387385, percent error 57.00
# Epoch     4, train loss 1.248635, train error 51.22,  val loss 1.261139, percent error 53.20
# Epoch     5, train loss 1.207853, train error 48.58,  val loss 1.254872, percent error 51.70
# Epoch     6, train loss 1.165692, train error 48.78,  val loss 1.183226, percent error 50.70
# Epoch     7, train loss 0.987807, train error 38.85,  val loss 1.017922, percent error 41.00
# Epoch     8, train loss 0.905297, train error 36.22,  val loss 0.946649, percent error 37.90
# Epoch     9, train loss 0.924036, train error 36.42,  val loss 1.005797, percent error 39.90
# Epoch    10, train loss 0.726319, train error 27.57,  val loss 0.790902, percent error 31.60
# Epoch    11, train loss 0.731394, train error 28.53,  val loss 0.792374, percent error 32.90
# Epoch    12, train loss 0.625538, train error 22.50,  val loss 0.671102, percent error 26.00
# Epoch    13, train loss 0.483093, train error 18.03,  val loss 0.544141, percent error 20.30
# Epoch    14, train loss 0.470100, train error 18.10,  val loss 0.527564, percent error 20.50
# Epoch    15, train loss 0.425053, train error 16.40,  val loss 0.496020, percent error 17.80
# Epoch    16, train loss 0.398164, train error 15.03,  val loss 0.468951, percent error 17.30
# Epoch    17, train loss 0.391045, train error 15.05,  val loss 0.489643, percent error 17.00
# Epoch    18, train loss 0.357869, train error 13.72,  val loss 0.450268, percent error 17.30
# Epoch    19, train loss 0.289492, train error 11.15,  val loss 0.399409, percent error 13.30
# Epoch    20, train loss 0.255654, train error 9.43,  val loss 0.382681, percent error 13.90
# Epoch    21, train loss 0.241340, train error 8.70,  val loss 0.369610, percent error 13.20
# Epoch    22, train loss 0.233721, train error 8.07,  val loss 0.359658, percent error 12.70
# Epoch    23, train loss 0.223693, train error 7.80,  val loss 0.371134, percent error 12.40
# Epoch    24, train loss 0.226329, train error 8.03,  val loss 0.389752, percent error 12.20
# Epoch    25, train loss 0.238054, train error 9.10,  val loss 0.399504, percent error 13.60
# Epoch    26, train loss 0.211047, train error 7.60,  val loss 0.376404, percent error 12.20
# Epoch    27, train loss 0.199542, train error 6.95,  val loss 0.359408, percent error 11.50
# Epoch    28, train loss 0.207320, train error 7.95,  val loss 0.375918, percent error 12.50
# Epoch    29, train loss 0.189375, train error 7.32,  val loss 0.350103, percent error 11.40
# Epoch    30, train loss 0.184159, train error 6.45,  val loss 0.368428, percent error 11.70
# Epoch    31, train loss 0.172514, train error 6.38,  val loss 0.374067, percent error 11.80
# Epoch    32, train loss 0.169428, train error 5.88,  val loss 0.377340, percent error 11.50
# Epoch    33, train loss 0.170310, train error 6.03,  val loss 0.388544, percent error 11.90
# Epoch    34, train loss 0.154532, train error 5.32,  val loss 0.355942, percent error 11.20
# Epoch    35, train loss 0.148860, train error 5.05,  val loss 0.377058, percent error 11.90
# Epoch    36, train loss 0.144674, train error 4.90,  val loss 0.367452, percent error 11.40
# Epoch    37, train loss 0.141495, train error 4.85,  val loss 0.392452, percent error 12.20
# Epoch    38, train loss 0.135238, train error 4.93,  val loss 0.379070, percent error 10.90
# Epoch    39, train loss 0.175685, train error 6.40,  val loss 0.448581, percent error 12.40
# Epoch    40, train loss 0.113428, train error 3.75,  val loss 0.371039, percent error 10.90
# Epoch    41, train loss 0.115085, train error 4.05,  val loss 0.371283, percent error 10.70
# Epoch    42, train loss 0.114712, train error 4.18,  val loss 0.377424, percent error 11.40
# Epoch    43, train loss 0.103585, train error 3.35,  val loss 0.361890, percent error 9.90
# Epoch    44, train loss 0.097246, train error 3.03,  val loss 0.370643, percent error 10.60
# Epoch    45, train loss 0.096900, train error 3.07,  val loss 0.372009, percent error 10.50
# Epoch    46, train loss 0.095151, train error 3.15,  val loss 0.381164, percent error 10.60
# Epoch    47, train loss 0.096221, train error 3.18,  val loss 0.382636, percent error 10.70
# Epoch    48, train loss 0.092810, train error 3.05,  val loss 0.376074, percent error 9.50
# Epoch    49, train loss 0.099633, train error 3.22,  val loss 0.385932, percent error 11.30
# Epoch    50, train loss 0.091463, train error 2.88,  val loss 0.391047, percent error 10.40
# Epoch    51, train loss 0.090293, train error 2.85,  val loss 0.397286, percent error 10.90
# Epoch    52, train loss 0.088356, train error 2.75,  val loss 0.376822, percent error 9.90
# Epoch    53, train loss 0.080324, train error 2.43,  val loss 0.364687, percent error 10.10
# Epoch    54, train loss 0.082475, train error 2.97,  val loss 0.388743, percent error 10.50
# Epoch    55, train loss 0.082444, train error 2.62,  val loss 0.390944, percent error 10.20
# Epoch    56, train loss 0.074134, train error 1.93,  val loss 0.384550, percent error 10.10
# Epoch    57, train loss 0.078783, train error 2.45,  val loss 0.391000, percent error 10.30
# Epoch    58, train loss 0.071358, train error 1.93,  val loss 0.391309, percent error 10.20
# Epoch    59, train loss 0.068120, train error 1.75,  val loss 0.380372, percent error 9.60
# Epoch    60, train loss 0.063081, train error 1.43,  val loss 0.378230, percent error 9.90
# Epoch    61, train loss 0.067897, train error 1.93,  val loss 0.393610, percent error 10.40
# Epoch    62, train loss 0.062199, train error 1.62,  val loss 0.381900, percent error 9.90
# Epoch    63, train loss 0.060797, train error 1.50,  val loss 0.381885, percent error 9.70
# Epoch    64, train loss 0.060521, train error 1.47,  val loss 0.383364, percent error 9.90
# Epoch    65, train loss 0.059824, train error 1.47,  val loss 0.382135, percent error 9.90
# Epoch    66, train loss 0.058883, train error 1.45,  val loss 0.389237, percent error 9.90
# Epoch    67, train loss 0.057042, train error 1.32,  val loss 0.382251, percent error 9.80
# Epoch    68, train loss 0.058091, train error 1.47,  val loss 0.386092, percent error 9.80
# Epoch    69, train loss 0.057502, train error 1.40,  val loss 0.392684, percent error 9.60
# Epoch    70, train loss 0.055852, train error 1.22,  val loss 0.385385, percent error 10.10
# Epoch    71, train loss 0.055588, train error 1.43,  val loss 0.394878, percent error 9.70
# Epoch    72, train loss 0.054927, train error 1.30,  val loss 0.398122, percent error 10.40
# Epoch    73, train loss 0.053098, train error 1.15,  val loss 0.389726, percent error 9.50
# Epoch    74, train loss 0.053629, train error 1.22,  val loss 0.397527, percent error 9.70
# Epoch    75, train loss 0.052389, train error 1.20,  val loss 0.397552, percent error 10.10
# Epoch    76, train loss 0.054299, train error 1.45,  val loss 0.396301, percent error 9.70
# Epoch    77, train loss 0.052897, train error 1.12,  val loss 0.399173, percent error 9.60
# Epoch    78, train loss 0.052091, train error 1.12,  val loss 0.408120, percent error 10.30
# Epoch    79, train loss 0.049325, train error 1.03,  val loss 0.400931, percent error 10.00
# Epoch    80, train loss 0.048800, train error 1.00,  val loss 0.398685, percent error 10.10
# Epoch    81, train loss 0.048767, train error 0.97,  val loss 0.408006, percent error 10.50
# Epoch    82, train loss 0.048161, train error 0.93,  val loss 0.405278, percent error 10.20
# Epoch    83, train loss 0.047963, train error 0.85,  val loss 0.404664, percent error 10.30
# Epoch    84, train loss 0.047191, train error 0.95,  val loss 0.402327, percent error 10.00
# Epoch    85, train loss 0.047052, train error 0.88,  val loss 0.407879, percent error 10.20
# Epoch    86, train loss 0.046901, train error 0.93,  val loss 0.404382, percent error 10.10
# Epoch    87, train loss 0.046507, train error 0.80,  val loss 0.402220, percent error 9.90
# Epoch    88, train loss 0.046090, train error 0.88,  val loss 0.403943, percent error 10.10
# Epoch    89, train loss 0.047147, train error 0.97,  val loss 0.410540, percent error 10.40
# Epoch    90, train loss 0.046884, train error 0.97,  val loss 0.414526, percent error 10.40
# Epoch    91, train loss 0.045978, train error 0.88,  val loss 0.404788, percent error 10.10
# Epoch    92, train loss 0.045873, train error 0.68,  val loss 0.415753, percent error 10.30
# Epoch    93, train loss 0.045026, train error 0.65,  val loss 0.412255, percent error 10.20
# Epoch    94, train loss 0.044275, train error 0.68,  val loss 0.407572, percent error 10.00
# Epoch    95, train loss 0.044220, train error 0.70,  val loss 0.415452, percent error 10.30
# Epoch    96, train loss 0.044400, train error 0.82,  val loss 0.410405, percent error 10.20
# Epoch    97, train loss 0.044003, train error 0.70,  val loss 0.417208, percent error 10.50
# Epoch    98, train loss 0.043696, train error 0.75,  val loss 0.417955, percent error 10.40
# Epoch    99, train loss 0.043586, train error 0.75,  val loss 0.418795, percent error 10.30
